# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
from sklearn.preprocessing import LabelEncoder
import numpy as np

pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колоноки

# %%
df = pd.read_csv('/Users/alina/Code/skillfactory/eda/stud_math.csv')

# %% [markdown]
# # Структура документа
# * Цели и задачи проекта
# * Первичная обработка/анализ данных
# * Анализ переменных на выбросы и пропуски
# * Корреляционный анализ количественных переменных
# * Анализ номинативных переменныъ
# * Выводы
# * Подготовка таблицы к построению модели
# * Комментарии
# * Ресурсы

# %% [markdown]
# # Цели и задачи проекта

# %% [markdown]
# Провести первичную обработку данных и отобрать переменные, которые могут влиять на успеваемость по математике учеников в возрасте от 15 до 22 лет, для того, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.
#
# В дальнейшем на основе отобранных переменных, будет построена модель, для своевременного определения учеников в группе риска.

# %% [markdown]
# # Первичный обработка/анализ данных

# %%
display(df.head(10))
df.info()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0   at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0    health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5     GP   M   16       U     LE3       T   4.0   3.0  services    other
# 6     GP   M   16     NaN     LE3       T   2.0   2.0     other    other
# 7     GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 8     GP   M   15       U     LE3       A   3.0   2.0  services    other
# 9     GP   M   15       U     NaN     NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %% [markdown]
# Описание переменных, которые содержит датасет:
#
# 1 school — аббревиатура школы, в которой учится ученик
#
# 2 sex — пол ученика ('F' - женский, 'M' - мужской)
#
# 3 age — возраст ученика (от 15 до 22)
#
# 4 address — тип адреса ученика ('U' - городской, 'R' - за городом)
#
# 5 famsize — размер семьи('LE3' <= 3, 'GT3' >3)
#
# 6 Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
#
# 7 Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
#
# 8 Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
#
# 9 Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
#
# 10 Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
#
# 11 reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
#
# 12 guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
#
# 13 traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
#
# 14 studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
#
# 15 failures — количество внеучебных неудач (n, если 1<=n<3, иначе 4)
#
# 16 schoolsup — дополнительная образовательная поддержка (yes или no)
#
# 17 famsup — семейная образовательная поддержка (yes или no)
#
# 18 paid — дополнительные платные занятия по математике (yes или no)
#
# 19 activities — дополнительные внеучебные занятия (yes или no)
#
# 20 nursery — посещал детский сад (yes или no)
#
# 21 higher — хочет получить высшее образование (yes или no)
#
# 22 internet — наличие интернета дома (yes или no)
#
# 23 romantic — в романтических отношениях (yes или no)
#
# 24 famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
#
# 25 freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)
#
# 26 goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
#
# 27 health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
#
# 28 absences — количество пропущенных занятий
#
# 29 score — баллы по госэкзамену по математике

# %% [markdown]
# ### Проверим, какое количество пропусков присутствует в датасете

# %%
# Function to calculate missing values by column
def missing_values_table(df):
    # Total missing values
    mis_val = df.isnull().sum()

    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)

    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

    # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(
        columns={0: 'Missing Values', 1: '% of Total Values'})

    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:, 1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)

    # Print some summary information
    print("Датафрейм содержит " + str(df.shape[1]) + " колонок.\n"
          "Есть " + str(mis_val_table_ren_columns.shape[0]) +
          " колонок с пропущенными значениями.")

    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
# Missing values statistics
missing_values = missing_values_table(df)
missing_values.head(27)
# Out:
# Датафрейм содержит 30 колонок.
# Есть 27 колонок с пропущенными значениями.
#                      Missing Values  % of Total Values
# Pstatus                          45               11.4
# paid                             40               10.1
# famsup                           39                9.9
# Fjob                             36                9.1
# internet                         34                8.6
# romantic                         31                7.8
# guardian                         31                7.8
# traveltime                       28                7.1
# famrel                           27                6.8
# famsize                          27                6.8
# Fedu                             24                6.1
# failures                         22                5.6
# higher                           20                5.1
# Mjob                             19                4.8
# address                          17                4.3
# ...

# %% [markdown]
# Максимальное количество пропусков составляет чуть больше 11%, что позволяет нам судить о досаточно качественных данных. Но для построения модели нужно будет либо удалить строки с отсутствующими данными, либо заполнить их используя среднее значение, либо заполнить данные используя метод, основанный на моделе предсказания (не уверена, что правильно перевела - impute data using model-based methods, in which models are defined to predict the missing values)
#
# Так как у нас есть пропуски в целевой переменной, то посмотрим их.

# %%
df[pd.isnull(df['score'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  \
# 201     GP   F   16       U     GT3       T   2.0   3.0  other     other
# 244     GP   F   18       U     GT3       T   2.0   1.0  other     other
# 270     GP   F   19     NaN     GT3       T   3.0   3.0  other  services
# 283     GP   F   18       U     GT3       T   1.0   1.0  other     other
# 312     GP   M   19       U     GT3       T   1.0   2.0  other  services
# 350     MS   M   19     NaN     GT3       T   1.0   1.0  other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 201  reputation   mother         1.0        2.0       0.0       yes    yes
# 244      course    other         2.0        3.0       0.0        no    yes
# 270        home    other         1.0        2.0       2.0        no    yes
# 283        home   mother         2.0        2.0       0.0       yes    NaN
# 312      course    other         1.0        2.0       1.0        no     no
# ...

# %%
# Удаляем наблюдения с пропусками и проверим результат
df.drop(df[pd.isnull(df['score'])].index, inplace=True)
df[pd.isnull(df['score'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %% [markdown]
# Так как в этих строках, кроме переменной score, были пропущены еще значения, то посмотрим произошли ли значимые изменения в самом датафрейме.

# %%
missing_values = missing_values_table(df)
missing_values.head(27)
# Out:
# Датафрейм содержит 30 колонок.
# Есть 26 колонок с пропущенными значениями.
#                      Missing Values  % of Total Values
# Pstatus                          45               11.6
# paid                             39               10.0
# famsup                           38                9.8
# Fjob                             36                9.3
# internet                         34                8.7
# guardian                         31                8.0
# romantic                         31                8.0
# traveltime                       28                7.2
# famrel                           27                6.9
# famsize                          27                6.9
# Fedu                             24                6.2
# failures                         22                5.7
# higher                           20                5.1
# Mjob                             19                4.9
# reason                           17                4.4
# ...

# %% [markdown]
# Видим, что распределение пропусков осталось премерно таким же.

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  389.000000  386.000000  365.000000  361.000000  382.000000  367.000000
# mean    16.673522    2.766839    2.627397    1.434903    2.036649    0.326975
# std      1.265662    1.094277    2.241790    0.692660    0.847239    0.729479
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000   40.000000    4.000000    4.000000    3.000000
#
#        studytime, granular      famrel    freetime       goout      health  \
# count           382.000000  362.000000  380.000000  382.000000  374.000000
# mean             -6.109948    3.930939    3.223684    3.094241    3.529412
# ...

# %% [markdown]
# Если посомтреть на всю таблицу, то можно увидеть, что в столбце famrel есть значение равное -1 - возможно это выброс. Также в столбце failures видим странное распределение данных. Обратим на это внимание при построении графиков. (Не уверена, что эта таблица показательна, так как большинство признаков категорийные)

# %%
# Посчитаем количество уникальных объектов, в каждом столбце
df.select_dtypes('object').apply(pd.Series.nunique, axis=0)
# Out:
# school        2
# sex           2
# address       2
# famsize       2
# Pstatus       2
# Mjob          5
# Fjob          5
# reason        4
# guardian      3
# schoolsup     2
# famsup        2
# paid          2
# activities    2
# nursery       2
# higher        2
# internet      2
# romantic      2
# dtype: int64

# %% [markdown]
# Видим, что в выборке участвует только две школы и большинство категорийных (бинарных) переменных имеет только по паре уникальных значений. Исключая Mjob, Fjob, reason, guardian.
#
# Столбцы Medu, Fedu, traveltime, studytime, failures, famrel, freetime, goout, health, хоть и содержат в себе числа, но также являются категорийными.
#
# Числовые - age, absences, score.

# %% [markdown]
# # Анализ столбцов

# %% [markdown]
# ## school

# %%
df['school'].value_counts(dropna=False, normalize=True)
# Out:
# GP    0.884319
# MS    0.115681
# Name: school, dtype: float64

# %% [markdown]
# В этом столбце нет пропусков и 88% студентов занимаются в школе GP.

# %% [markdown]
# Предположение - в школе GP, лучше готовят к математике, так как от туда больше учеников

# %%
df.groupby(['school'])['score'].count()
# Out:
# school
# GP    343
# MS     44
# Name: score, dtype: int64

# %%
df.groupby(['school'])['score'].mean()
# Out:
# school
# GP    52.667638
# MS    49.772727
# Name: score, dtype: float64

# %% [markdown]
# Похоже, что в обоих школах подготовка на одинаковом уровне учеников.

# %% [markdown]
# ## sex

# %%
df['sex'].value_counts(dropna=False, normalize=True)
# Out:
# F    0.524422
# M    0.475578
# Name: sex, dtype: float64

# %% [markdown]
# В выборке присутствует 52% девушек и 48% молодых людей.

# %% [markdown]
# Предположение - у молодых людей выше оценка за экзамен, так как у них, считается, лучше развиты математические способности.

# %%
print(df.groupby(['sex'])['score'].count())
print(df.groupby(['sex'])['score'].mean())
# Out:
# sex
# F    204
# M    185
# Name: score, dtype: int64
# sex
# F    50.098039
# M    54.648649
# Name: score, dtype: float64

# %%
pd.crosstab(df.sex, df.score, margins=True).style.background_gradient(
    cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col0 {
#             background-color:  #aed666;
#             color:  #000000;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col3 {
#             background-color:  #279366;
#             color:  #000000;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d9bd19b8_aa8c_11ea_bad7_186590d6f867row0_col6 {
#             background-color:  #afd766;
#             color:  #000000;
# ...

# %% [markdown]
# Действительно, у молодых людей средняя оценка незначительно выше.

# %% [markdown]
# ## age

# %%
df['age'].value_counts(dropna=False, normalize=True)
# Out:
# 16    0.264781
# 17    0.251928
# 15    0.210797
# 18    0.205656
# 19    0.053985
# 20    0.007712
# 22    0.002571
# 21    0.002571
# Name: age, dtype: float64

# %%
df.age.hist(bins=8)

# %% [markdown]
# Можно заметить, что количество учеников возраста 21 и 22 года одинаково низкое в выборке. Проверим, что это не выбросы.

# %%
sns.boxplot(df['age'])

# %%
outliers = []


def detect_outlier(data_1):

    threshold = 3
    mean_1 = np.mean(data_1)
    std_1 = np.std(data_1)

    for y in data_1:
        z_score = (y - mean_1)/std_1
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
outlier_datapoints = detect_outlier(df.age)
print(outlier_datapoints)
# Out:
# [22, 21]

# %% [markdown]
# Похоже, что есть одни выброс, который может в дальнейшем негативно повлиять на нашу модель

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR, Q1, Q3)
# Out:
# age                     2.0
# Medu                    2.0
# Fedu                    1.0
# traveltime              1.0
# studytime               1.0
# failures                0.0
# studytime, granular     3.0
# famrel                  1.0
# freetime                1.0
# goout                   2.0
# health                  2.0
# absences                8.0
# score                  30.0
# dtype: float64 age                    16.0
# Medu                    2.0
# Fedu                    2.0
# traveltime              1.0
# studytime               1.0
# failures                0.0
# studytime, granular    -6.0
# famrel                  4.0
# freetime                3.0
# goout                   2.0
# health                  3.0
# absences                0.0
# score                  40.0
# Name: 0.25, dtype: float64 age                    18.0
# Medu                    4.0
# Fedu                    3.0
# traveltime              2.0
# studytime               2.0
# ...

# %%
sns.scatterplot(x='age', y='score', data=df)

# %% [markdown]
# Да, похоже, что значения равные 21 и 22 необходимо удалить

# %%
df = df.loc[df.age < 21]

# %%
# проверяем и строим гистограмму по новым данным
df['age'].value_counts()
# Out:
# 16    103
# 17     98
# 15     82
# 18     80
# 19     21
# 20      3
# Name: age, dtype: int64

# %%
df.age.hist(bins=6)

# %% [markdown]
# В столбце age не было пропушенных значений, но мы нашли два выброса. Подтвердив их,  помощью расчета z-индекса и Scatter Plot.

# %% [markdown]
# Предположение - ученики 15-16-17 лет сдают экзамен лучше, чем оставшаяся группа, так как более старшие могут быть не заинтересованы в обучении или оставались на второй год.

# %%
print(df.groupby(['age'])['score'].count())
print(df.groupby(['age'])['score'].mean())
# Out:
# age
# 15     82
# 16    103
# 17     98
# 18     80
# 19     21
# 20      3
# Name: score, dtype: int64
# age
# 15    56.280488
# 16    55.194175
# 17    51.377551
# 18    48.312500
# 19    40.238095
# 20    70.000000
# Name: score, dtype: float64

# %% [markdown]
# Да, по среднему значению видим, что чем моложе ученик, тем лучше средний результат. Думаю, что это важная переменная для дальнейшего анализа.

# %% [markdown]
# ## address

# %%
df['address'].value_counts(dropna=False, normalize=True)
# Out:
# U      0.746835
# R      0.210127
# NaN    0.043038
# Name: address, dtype: float64

# %%
df[pd.isnull(df['address'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 6       GP   M   16     NaN     LE3       T   2.0   2.0     other     other
# 52      GP   M   15     NaN     LE3       A   4.0   2.0    health       NaN
# 75      GP   M   15     NaN     GT3       T   4.0   3.0   teacher     other
# 92      GP   F   16     NaN     LE3       T   NaN   1.0     other     other
# 96      GP   M   16     NaN     GT3     NaN   4.0   3.0  services     other
# 159     GP   M   16     NaN     GT3       T   3.0   NaN     other  services
# 168     GP   F   16     NaN     GT3       T   2.0   2.0     other     other
# 241     GP   M   17     NaN     LE3       A   4.0   4.0   teacher     other
# 254     GP   M   17     NaN     NaN       T   2.0   1.0     other     other
# 270     GP   F   19     NaN     GT3       T   3.0   3.0     other  services
# 292     GP   F   18     NaN     LE3       T   2.0   1.0  services   at_home
# ...

# %%
df['address'].fillna('U', inplace=True)

# %%
df[pd.isnull(df['address'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %% [markdown]
# В столбце address пропущенные значения заменили на U, так как по таблице мы видим, что все студенты добираются до школы максимум 30 минут, после чего проверили вывод.
# 75% учеников имеют городской адрес.

# %% [markdown]
# Предположение - ученики за городом хуже сдают экзамен, так как у них остается меньше времени на подготовку из-за долгой дороги

# %%
print(df.groupby(['address'])['score'].count())
print(df.groupby(['address'])['score'].mean())
# Out:
# address
# R     82
# U    305
# Name: score, dtype: int64
# address
# R    47.073171
# U    53.754098
# Name: score, dtype: float64

# %% [markdown]
# Предполжеие подтвердилось, видим, что средний балл у городских учеников выше.

# %% [markdown]
# ## famsize

# %%
df['famsize'].value_counts(dropna=False, normalize=True)
# Out:
# GT3    0.655527
# LE3    0.275064
# NaN    0.069409
# Name: famsize, dtype: float64

# %%
df[pd.isnull(df['famsize'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 9       GP   M   15       U     NaN     NaN   3.0   4.0     other     other
# 32      GP   M   15       R     NaN       T   4.0   3.0   teacher   at_home
# 36      GP   M   15       U     NaN       T   4.0   3.0   teacher  services
# 76      GP   M   15       U     NaN       T   4.0   0.0   teacher     other
# 78      GP   M   17       U     NaN       T   2.0   1.0     other     other
# 79      GP   F   16       U     NaN       T   3.0   4.0   at_home     other
# 114     GP   M   15       R     NaN       T   2.0   1.0    health  services
# 128     GP   M   18       R     NaN       T   2.0   2.0       NaN     other
# 129     GP   M   16       R     NaN       T   4.0   4.0   teacher   teacher
# 167     GP   F   16       U     NaN       T   4.0   2.0    health  services
# ...

# %% [markdown]
# Большинство учеников живут в семьях, где больше трех человек. Заполним пропуски наиболее частотным значением.

# %%
df['famsize'].fillna('GT3', inplace=True)

# %%
df[pd.isnull(df['famsize'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %% [markdown]
# Предположение - ученики, которые живут в небольших семьях набирают больше баллов, так как их меньше отвлекают и больше остается финансовых ресурсов на подготовку.

# %%
print(df.groupby(['famsize'])['score'].count())
print(df.groupby(['famsize'])['score'].mean())
# Out:
# famsize
# GT3    280
# LE3    107
# Name: score, dtype: int64
# famsize
# GT3    51.446429
# LE3    54.672897
# Name: score, dtype: float64

# %% [markdown]
# С незначительным перевесом, но все-таки, средний балл выше в семьях, где меньше трех человек.

# %% [markdown]
# ## Pstatus

# %%
df['Pstatus'].value_counts(dropna=False, normalize=True)
# Out:
# T      0.791774
# NaN    0.115681
# A      0.092545
# Name: Pstatus, dtype: float64

# %%
df[pd.isnull(df['Pstatus'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 9       GP   M   15       U     GT3     NaN   3.0   4.0     other     other
# 11      GP   F   15       U     GT3     NaN   2.0  40.0  services     other
# 15      GP   F   16       U     GT3     NaN   4.0   4.0    health     other
# 25      GP   F   16       U     GT3     NaN   2.0   2.0  services  services
# 28      GP   M   16       U     LE3     NaN   3.0   4.0  services     other
# 54      GP   F   15       U     LE3     NaN   3.0   3.0       NaN     other
# 63      GP   F   16       U     GT3     NaN   4.0   3.0   teacher    health
# 67      GP   F   16       U     GT3     NaN   3.0   NaN  services     other
# 81      GP   M   15       U     GT3     NaN   2.0   3.0     other     other
# 96      GP   M   16       U     GT3     NaN   4.0   3.0  services     other
# ...

# %% [markdown]
# Параметр Pstatus имеет самое большое количество неизвестных значений во всей таблице. Я попробовала проаналзировать есть ли какая-либо связь между этим столбцом и значениями в других колонках, но визуально таких связей не нашла. Поэтому пока предлагаю заполнить пропуски по наиболее частотному значению, а в дальнейшем посмотреть на сколько этот параметр влияет на целевую переменную, на сколько он важен для нас и, при необходимости, провести более тщательную подготовку.

# %%
df['Pstatus'].fillna('T', inplace=True)
df[pd.isnull(df['Pstatus'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %%
df['Pstatus'].value_counts(dropna=False, normalize=True)
# Out:
# T    0.906977
# A    0.093023
# Name: Pstatus, dtype: float64

# %% [markdown]
# У 91% учеников родители живут вместе. Не уверена, что имеет смысл оставлять столбец с практически с одинаковым значением на всем протяжении.

# %%
print(df.groupby(['Pstatus'])['score'].count())
print(df.groupby(['Pstatus'])['score'].mean())
# Out:
# Pstatus
# A     36
# T    351
# Name: score, dtype: int64
# Pstatus
# A    55.138889
# T    52.051282
# Name: score, dtype: float64

# %% [markdown]
# Средний балл получился выше у семей, что живут раздельно, но мне кажется, стоит учитывать, насколько мал их процент в общей выборке (9%).

# %% [markdown]
# ## Medu

# %%
df['Medu'].value_counts(dropna=False, normalize=True)
# Out:
# 4.0    0.336761
# 2.0    0.257069
# 3.0    0.246787
# 1.0    0.143959
# 0.0    0.007712
# NaN    0.007712
# Name: Medu, dtype: float64

# %%
df[pd.isnull(df['Medu'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 92      GP   F   16       U     LE3       T   NaN   1.0     other     other
# 193     GP   M   16       R     GT3       T   NaN   3.0  services  services
# 239     GP   M   18       U     GT3       T   NaN   2.0     other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 92         home   father         1.0        2.0       0.0       yes    yes
# 193  reputation   mother         1.0        1.0       0.0        no    yes
# 239  reputation   father         1.0        2.0       1.0        no     no
#
#     paid activities nursery  studytime, granular higher internet romantic  \
# 92    no         no     yes                 -6.0    yes       no       no
# 193   no        yes     yes                 -3.0    yes      yes       no
# 239   no         no     yes                 -6.0     no      NaN      NaN
#
#      famrel  freetime  goout  health  absences  score
# ...

# %%
df['Medu'].fillna(4.0, inplace=True)
df[pd.isnull(df['Medu'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %%
df['Medu'].value_counts(dropna=False, normalize=True)
# Out:
# 4.0    0.346253
# 2.0    0.258398
# 3.0    0.245478
# 1.0    0.142119
# 0.0    0.007752
# Name: Medu, dtype: float64

# %%
sns.boxplot(df['Medu'])

# %%
sns.countplot(x='Medu', data=stud, label='Medu')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92612471d951> in <module>
# ----> 1 sns.countplot(x='Medu', data=stud, label='Medu')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# В столбце с образованием матерей не было выбросов, только несколько пропусков. Большинство матерей получили какое либо образования, но есть те, у кого вообще нет образования (0) - их меньше 1%. У 14% - 4 класса (1), 25% - 5-9 классов (2), 24% - среднее специальное или 11 классов (3), 34% - высшее.

# %% [markdown]
# ## Fedu

# %%
df['Fedu'].value_counts(dropna=False, normalize=True)
# Out:
# 2.0     0.269923
# 3.0     0.241645
# 4.0     0.226221
# 1.0     0.192802
# NaN     0.061697
# 0.0     0.005141
# 40.0    0.002571
# Name: Fedu, dtype: float64

# %%
# предполагаем, что значение 40 появилось в результате ошибки ввода, заменяем его на 4
df.loc[df['Fedu'] == 40, 'Fedu'] = 4.0

# %%
sns.boxplot(df['Fedu'])

# %%
df[pd.isnull(df['Fedu'])]
# Out:
#     school sex  age address famsize Pstatus Medu  Fedu      Mjob      Fjob  \
# 21      GP   M   15       U     GT3       T    4   NaN    health    health
# 42      GP   M   15       U     GT3       T    4   NaN  services   teacher
# 46      GP   F   16       U     LE3       A    3   NaN     other  services
# 57      GP   M   15       U     GT3       T    4   NaN   teacher    health
# 58      GP   M   15       U     LE3       T    1   NaN     other   at_home
# 67      GP   F   16       U     GT3       T    3   NaN  services     other
# 137     GP   F   16       U     GT3       A    3   NaN     other     other
# 142     GP   F   15       U     GT3       T    4   NaN   teacher  services
# 159     GP   M   16       U     GT3       T    3   NaN     other  services
# 161     GP   M   15       R     GT3       T    3   NaN     other       NaN
# 180     GP   M   16       U     GT3       T    4   NaN   teacher     other
# ...

# %%
df['Fedu'].value_counts(dropna=False, normalize=True)
# Out:
# 2.0    0.271318
# 3.0    0.242894
# 4.0    0.229974
# 1.0    0.188630
# NaN    0.062016
# 0.0    0.005168
# Name: Fedu, dtype: float64

# %%
df.Fedu.hist(bins=5)

# %%
df.Fedu.median()
# Out:
# 3.0

# %%
df.Fedu.mode()
# Out:
# 0    2.0
# dtype: float64

# %%
df['Fedu'].fillna(4.0, inplace=True)
df[pd.isnull(df['Fedu'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %%
df['Fedu'].value_counts(dropna=False, normalize=True)
# Out:
# 4.0    0.291990
# 2.0    0.271318
# 3.0    0.242894
# 1.0    0.188630
# 0.0    0.005168
# Name: Fedu, dtype: float64

# %%
sns.boxplot(df['Fedu'])

# %% [markdown]
# В столбце с образованием отцов, один выброс - его заменила. Большинство отцов получили какое либо образования, но есть те, у кого вообще нет образования (0) - их меньше 1%. У 18% - 4 класса (1), 27% - 5-9 классов (2), 24% - среднее специальное или 11 классов (3), 23% - высшее. Похожую ситуацию мы видели в столбце, связанным с образованием у матерей.

# %% [markdown]
# Предположение - ученики набрали больше баллов у которых родители образованы.

# %%
# создаем новый столбец, в который соберем максимальное значения из колонок про образование родителей
df['Pedu'] = df.apply(lambda x: x.Medu if x.guardian == 'mother'
                      else (x.Fedu if x.guardian == 'father' else x[['Medu', 'Fedu']].max()), axis=1)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3       T   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 389     MS   F   18       U     GT3       T   1.0   1.0     other     other
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
# ...

# %%
df.groupby(['Pedu'])['score'].count()
# Out:
# Pedu
# 0.0      1
# 1.0     53
# 2.0    102
# 3.0    102
# 4.0    129
# Name: score, dtype: int64

# %%
df.groupby(['Pedu'])['score'].mean()
# Out:
# Pedu
# 0.0    75.000000
# 1.0    45.377358
# 2.0    48.284314
# 3.0    52.401961
# 4.0    58.178295
# Name: score, dtype: float64

# %%
# проверим влияет ли, если мать образована на обучение ребенка
df['MPedu'] = df.apply(lambda x: x.Medu if x.Medu
                       else x.Fedu, axis=1)

# %%
df.groupby(['MPedu'])['score'].count()
# Out:
# MPedu
# 1.0     56
# 2.0    102
# 3.0     95
# 4.0    134
# Name: score, dtype: int64

# %%
df.groupby(['MPedu'])['score'].mean()
# Out:
# MPedu
# 1.0    43.303571
# 2.0    50.098039
# 3.0    51.947368
# 4.0    58.097015
# Name: score, dtype: float64

# %%
# влияет ли образование отца на результаты по экзаменам
df['PPedu'] = df.apply(lambda x: x.Fedu if x.Fedu else 0, axis=1)

# %%
df.groupby(['PPedu'])['score'].count()
# Out:
# PPedu
# 0.0      2
# 1.0     74
# 2.0    128
# 3.0     94
# 4.0     89
# Name: score, dtype: int64

# %%
df.groupby(['PPedu'])['score'].mean()
# Out:
# PPedu
# 0.0    65.000000
# 1.0    46.486486
# 2.0    51.914062
# 3.0    54.042553
# 4.0    55.730337
# Name: score, dtype: float64

# %% [markdown]
# Предлагаю для дальнейшей работы оставить столбец Pedu, так как мы видим по среднему значению, что чем образованнее родители, тем лучше оценка.

# %% [markdown]
# ## Mjob

# %%
df['Mjob'].value_counts(dropna=False, normalize=True)
# Out:
# other       0.326478
# services    0.251928
# at_home     0.149100
# teacher     0.141388
# health      0.082262
# NaN         0.048843
# Name: Mjob, dtype: float64

# %%
df['Mjob'].fillna('other', inplace=True)
df[pd.isnull(df['Mjob'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score, Pedu, MPedu, PPedu]
# Index: []

# %%
df['Mjob'].value_counts(dropna=False, normalize=True)
# Out:
# other       0.374677
# services    0.250646
# at_home     0.149871
# teacher     0.142119
# health      0.082687
# Name: Mjob, dtype: float64

# %% [markdown]
# У 37% учеников матери работают по направлению не попадающему не в одну из представленных категорий, у 25% - на государственной службе, 14% тех, кто не работает или работает учителем, и 8% в сфере здравоохранения. В столбце были пропуски, которые заменила на наиболее частотное значение.

# %% [markdown]
# Предположение - сфера работы матери никак не влияет на оценку. Или ученики у которых мать не работает сдают экзамен лучше, так как у них больше возможность для помощи.

# %%
df.groupby(['Mjob'])['score'].count()
# Out:
# Mjob
# at_home      58
# health       32
# other       145
# services     97
# teacher      55
# Name: score, dtype: int64

# %%
df.groupby(['Mjob'])['score'].mean()
# Out:
# Mjob
# at_home     45.689655
# health      60.625000
# other       50.379310
# services    54.896907
# teacher     55.181818
# Name: score, dtype: float64

# %% [markdown]
# Как оказалось, что на оборот, и детей, у которых мать не работает можно добавить в группу риска.

# %% [markdown]
# ## Fjob

# %%
df['Fjob'].value_counts(dropna=False, normalize=True)
# Out:
# other       0.498715
# services    0.254499
# NaN         0.092545
# teacher     0.074550
# at_home     0.041131
# health      0.038560
# Name: Fjob, dtype: float64

# %%
df['Fjob'].fillna('other', inplace=True)
df[pd.isnull(df['Fjob'])]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, studytime, granular, higher, internet, romantic, famrel, freetime, goout, health, absences, score, Pedu, MPedu, PPedu]
# Index: []

# %%
df['Fjob'].value_counts(dropna=False, normalize=True)
# Out:
# other       0.591731
# services    0.253230
# teacher     0.074935
# at_home     0.041344
# health      0.038760
# Name: Fjob, dtype: float64

# %% [markdown]
# У 59% учеников матери работают по направлению не попадающему не в одну из представленных категорий, у 25% - на государственной службе, 4% тех, кто не работает, 7% работает учителем, и 4% в сфере здравоохранения. В столбце были пропуски, которые заменила на наиболее частотное значение.

# %% [markdown]
# Предположение - сфера работы отца никак не влияет на итоговую оценку.

# %%
df.groupby(['Fjob'])['score'].count()
# Out:
# Fjob
# at_home      16
# health       15
# other       229
# services     98
# teacher      29
# Name: score, dtype: int64

# %%
df.groupby(['Fjob'])['score'].mean()
# Out:
# Fjob
# at_home     51.875000
# health      55.666667
# other       51.965066
# services    50.561224
# teacher     59.827586
# Name: score, dtype: float64

# %% [markdown]
# Остаюсь при мнении, что сфера работы отца не влияет на итоговую оценку.

# %% [markdown]
# ## reason

# %%
df['reason'].value_counts(dropna=False, normalize=True)
# Out:
# course        0.346253
# reputation    0.263566
# home          0.260982
# other         0.085271
# NaN           0.043928
# Name: reason, dtype: float64

# %%
df['reason'].fillna('course', inplace=True)
df[pd.isnull(df['reason'])]
df['reason'].value_counts(dropna=False, normalize=True)
# Out:
# course        0.390181
# reputation    0.263566
# home          0.260982
# other         0.085271
# Name: reason, dtype: float64

# %% [markdown]
# В этом столбце были пропуски, котоыре заменили наиболее частым значением. 39% учеников выбрали школу из-за образовательно программа ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)

# %% [markdown]
# Предположение - в школе с образовательное программой готовят лучше к экзаменам.

# %%
df.groupby(['reason'])['score'].count()
# Out:
# reason
# course        151
# home          101
# other          33
# reputation    102
# Name: score, dtype: int64

# %%
df.groupby(['reason'])['score'].mean()
# Out:
# reason
# course        50.000000
# home          51.188119
# other         56.363636
# reputation    55.637255
# Name: score, dtype: float64

# %% [markdown]
# Предположение не оправдалось и разброс между результатом и причиной не очень большой, стоит в дальнейшем проверить статистическую значимость данного параметра.

# %% [markdown]
# ## guardian

# %%
df['guardian'].value_counts(dropna=False, normalize=True)
# Out:
# mother    0.637532
# father    0.221080
# NaN       0.079692
# other     0.061697
# Name: guardian, dtype: float64

# %%
df['guardian'].fillna('mother', inplace=True)
df[pd.isnull(df['guardian'])]
df['guardian'].value_counts(dropna=False, normalize=True)
# Out:
# mother    0.715762
# father    0.222222
# other     0.062016
# Name: guardian, dtype: float64

# %% [markdown]
# В столбце были только пропущенные значения. У 72% опекун mother, у 22% - отец, оставшиеся ученики указали - другой.

# %% [markdown]
# Предположение - у студентов, кто опекун мать сдают экзамен лучше, чем отец. Либо нет никакой связи.

# %%
print(df.groupby(['guardian'])['score'].count())
print(df.groupby(['guardian'])['score'].mean())
# Out:
# guardian
# father     86
# mother    277
# other      24
# Name: score, dtype: int64
# guardian
# father    53.430233
# mother    52.581227
# other     45.625000
# Name: score, dtype: float64

# %%
# попробуем вывести студентов, которые в графе опекун, указали "другое", в отдельный столбец
df['other_guardian'] = df.apply(lambda x: 1 if x.guardian == 'other'
                                else 0, axis=1)

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A   4.0   4.0  at_home  teacher
# 1     GP   F   17       U     GT3       T   1.0   1.0  at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0  at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0   health    other
# 4     GP   F   16       U     GT3       T   3.0   3.0    other    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother         2.0        2.0       0.0       yes     no   no
# 1  course   father         1.0        2.0       0.0        no    yes   no
# 2   other   mother         1.0        2.0       3.0       yes     no  NaN
# 3    home   mother         1.0        3.0       0.0        no    yes  yes
# 4    home   father         1.0        2.0       0.0        no    yes  yes
#
#   activities nursery  studytime, granular higher internet romantic  famrel  \
# ...

# %% [markdown]
# Частично этот столбец задействован в новом столбце Pedu, поэтому предлагаю создать новый other_gardian для построения модели.

# %% [markdown]
# ## traveltime

# %%
df['traveltime'].value_counts(dropna=False, normalize=True)
# Out:
# 1.0    0.614396
# 2.0    0.241645
# NaN    0.071979
# 3.0    0.053985
# 4.0    0.017995
# Name: traveltime, dtype: float64

# %%
df[pd.isnull(df['traveltime'])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 26      GP   M   15       U     GT3       T   2.0   2.0     other       NaN
# 30      GP   M   15       U     GT3       T   4.0   4.0    health  services
# 35      GP   F   15       U     GT3       T   2.0   3.0     other     other
# 37      GP   M   16       R     GT3       A   4.0   4.0     other   teacher
# 59      GP   F   16       U     GT3       T   4.0   2.0       NaN       NaN
# 68      GP   F   15       R     LE3       T   2.0   2.0    health       NaN
# 70      GP   M   16       U     GT3       T   3.0   1.0     other     other
# 104     GP   M   15       U     GT3       A   3.0   4.0       NaN     other
# 112     GP   F   16       U     GT3     NaN   2.0   2.0   at_home     other
# 132     GP   F   17       U     LE3       T   2.0   2.0     other     other
# 134     GP   M   15       R     GT3       T   3.0   4.0   at_home   teacher
# ...

# %%
df['traveltime'].fillna(1.0, inplace=True)

# %%
df['traveltime'].value_counts(dropna=False, normalize=True)
# Out:
# 1.0    0.684755
# 2.0    0.242894
# 3.0    0.054264
# 4.0    0.018088
# Name: traveltime, dtype: float64

# %% [markdown]
# 68% учеников добираются до школы меньше, чем за 15 минут, 24% тратят на дорогу до школы от 15 до 30 минут, 5% и 2% проводят в дороге до часа и больше часа.

# %% [markdown]
# Предположение - чем меньше времени тратишь на дорогу, тем лучше результат за экзамен, так как нет усталости от дороги и больше времени.

# %%
sns.boxplot(df['traveltime'])

# %%
print(df.groupby(['traveltime'])['score'].count())
print(df.groupby(['traveltime'])['score'].mean())
# Out:
# traveltime
# 1.0    237
# 2.0     94
# 3.0     21
# 4.0      7
# Name: score, dtype: int64
# traveltime
# 1.0    53.713080
# 2.0    51.755319
# 3.0    46.428571
# 4.0    50.000000
# Name: score, dtype: float64

# %% [markdown]
# Видно, что те, кто тратит на дорогу меньше времени и лучше сдают экзамен. Но значения равные 4 выглядят как выброс на боксплоте, и по средним значениям. Их достаточно мало, поэтому предлагаю их удалить.

# %%
df = df[df.traveltime != 4.0]

# %%
sns.boxplot(df['traveltime'])

# %%
print(df.groupby(['traveltime'])['score'].count())
print(df.groupby(['traveltime'])['score'].mean())
# Out:
# traveltime
# 1.0    265
# 2.0     94
# 3.0     21
# Name: score, dtype: int64
# traveltime
# 1.0    53.075472
# 2.0    51.755319
# 3.0    46.428571
# Name: score, dtype: float64

# %% [markdown]
# ## studytime

# %%
df['studytime'].value_counts(dropna=False, normalize=True)
# Out:
# 2.0    0.485861
# 1.0    0.264781
# 3.0    0.161954
# 4.0    0.069409
# NaN    0.017995
# Name: studytime, dtype: float64

# %%
sns.boxplot(df['studytime'])

# %%
# заменим пропуски на наиболее частотное
df['studytime'].fillna(2.0, inplace=True)
df[pd.isnull(df['studytime'])]
df['studytime'].value_counts(dropna=False, normalize=True)
# Out:
# 2.0    0.506460
# 1.0    0.260982
# 3.0    0.162791
# 4.0    0.069767
# Name: studytime, dtype: float64

# %% [markdown]
# 50% учеников тратят по 2-5 часов на учёбу помимо школы, 26% - меньше двух часов, 16% - 5-10 часов и 7% - больше 10 часов. Хоть на графике значение соответствующие 4 (больше 10 часов) и обозначается, как выброс, но мне кажется, его не стоит удалять до того, как посмотрим его влияние на целевую переменную.

# %% [markdown]
# Предположение - чем больше времени на учебу - тем лучше результат.

# %%
print(df.groupby(['studytime'])['score'].count())
print(df.groupby(['studytime'])['score'].mean())
# Out:
# studytime
# 1.0    101
# 2.0    196
# 3.0     63
# 4.0     27
# Name: score, dtype: int64
# studytime
# 1.0    49.702970
# 2.0    51.403061
# 3.0    57.777778
# 4.0    56.296296
# Name: score, dtype: float64

# %% [markdown]
# Зачастую, больше времени уделенное учебе, приводит к лучшему результату.

# %% [markdown]
# ## failures

# %%
df['failures'].value_counts(dropna=False, normalize=True)
# Out:
# 0.0    0.745501
# 1.0    0.123393
# NaN    0.056555
# 2.0    0.038560
# 3.0    0.035990
# Name: failures, dtype: float64

# %%
sns.boxplot(df['failures'])

# %%
# заменим пропуски на наиболее частотное
df['failures'].fillna(0.0, inplace=True)
df[pd.isnull(df['failures'])]
df['failures'].value_counts(dropna=False, normalize=True)
# Out:
# 0.0    0.806202
# 1.0    0.124031
# 2.0    0.038760
# 3.0    0.031008
# Name: failures, dtype: float64

# %%
sns.boxplot(df['failures'])

# %% [markdown]
# Похоже, что 81% учеников не имели внеучебных неудач, у 12% - 1 неудача, у 4% - 2, и у 3% - 3. Больше трех не было ни у кого.

# %% [markdown]
# Предположение - чем меньше неудач, тем лучше результат за экзамен.

# %%
print(df.groupby(['failures'])['score'].count())
print(df.groupby(['failures'])['score'].mean())
# Out:
# failures
# 0.0    312
# 1.0     48
# 2.0     15
# 3.0     12
# Name: score, dtype: int64
# failures
# 0.0    56.121795
# 1.0    40.000000
# 2.0    32.333333
# 3.0    28.333333
# Name: score, dtype: float64

# %% [markdown]
# Да, предположение подтвердилось.

# %% [markdown]
# ## schoolsup

# %%
df['schoolsup'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.850900
# yes    0.125964
# NaN    0.023136
# Name: schoolsup, dtype: float64

# %%
# заменим пропуски на наиболее частотное
df['schoolsup'].fillna('no', inplace=True)
df[pd.isnull(df['schoolsup'])]
df['schoolsup'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.873385
# yes    0.126615
# Name: schoolsup, dtype: float64

# %% [markdown]
# 87% учеников не имеют дополнительной образовательной поддержки

# %% [markdown]
# Предположение - ученики с доп поддержкой сдают лучше экзамен.

# %%
print(df.groupby(['schoolsup'])['score'].count())
print(df.groupby(['schoolsup'])['score'].mean())
# Out:
# schoolsup
# no     338
# yes     49
# Name: score, dtype: int64
# schoolsup
# no     53.106509
# yes    47.040816
# Name: score, dtype: float64

# %% [markdown]
# Пока сложно решить с этим столбцом, так как с одной стороны достаточно небольшое количество от общей массы учеников имеют поддержку, не уверена, но зато эти 13% показывают результат хуже.

# %% [markdown]
# ## famsup

# %%
df['famsup'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.555270
# no     0.347044
# NaN    0.097686
# Name: famsup, dtype: float64

# %%
# заменим пропуски на наиболее частотное
df['famsup'].fillna('yes', inplace=True)
df[pd.isnull(df['famsup'])]
df['famsup'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.656331
# no     0.343669
# Name: famsup, dtype: float64

# %% [markdown]
# 65% ученикам получают семейную образовательную поддержку.

# %% [markdown]
# Предположение - ученики с поддержкой сдают лучше.
# Предположение - объединить два столбца schoolsup и famsup, 1 у тех, у кого есть хоть какая-то подддержка, 0 - нет.

# %%
print(df.groupby(['famsup'])['score'].count())
print(df.groupby(['famsup'])['score'].mean())
# Out:
# famsup
# no     133
# yes    254
# Name: score, dtype: int64
# famsup
# no     52.293233
# yes    52.362205
# Name: score, dtype: float64

# %%
df['any_sup'] = df.apply(lambda x: 1 if (
    x.famsup == 'yes' or x.schoolsup == 'yes') else 0, axis=1)
# Out:
# /Users/alina/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3       T   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health     other
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 389     MS   F   18       U     GT3       T   1.0   1.0     other     other
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
# ...

# %%
del df['anysup']

# %% [markdown]
# ## paid

# %%
df['paid'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.506427
# yes    0.393316
# NaN    0.100257
# Name: paid, dtype: float64

# %%
# заменим пропуски на наиболее частотное
df['paid'].fillna('no', inplace=True)
df[pd.isnull(df['paid'])]
df['paid'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.604651
# yes    0.395349
# Name: paid, dtype: float64

# %% [markdown]
# 60% не берут дополнительные платные занятия по математике.

# %% [markdown]
# Предположение - те, кто занимается дополнительно сдают лучше.

# %%
print(df.groupby(['paid'])['score'].count())
print(df.groupby(['paid'])['score'].mean())
# Out:
# paid
# no     234
# yes    153
# Name: score, dtype: int64
# paid
# no     50.598291
# yes    55.000000
# Name: score, dtype: float64

# %% [markdown]
# Да, предположение подтвердилось.

# %% [markdown]
# ## activities

# %%
df['activities'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.493573
# no     0.470437
# NaN    0.035990
# Name: activities, dtype: float64

# %%
df['activities'].fillna('yes', inplace=True)
df[pd.isnull(df['activities'])]
df['activities'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.5323
# no     0.4677
# Name: activities, dtype: float64

# %% [markdown]
# 53% учеников ходят на дополнительные внеучебные занятия, а 47% - нет.

# %% [markdown]
# Предположение - те, кто ходят сдают лучше, так как у них более активная жизненная позиция и шире кругозор.

# %%
print(df.groupby(['activities'])['score'].count())
print(df.groupby(['activities'])['score'].mean())
# Out:
# activities
# no     181
# yes    206
# Name: score, dtype: int64
# activities
# no     52.348066
# yes    52.330097
# Name: score, dtype: float64

# %% [markdown]
# Не похоже, что есть какая-то взаимосвязь между дополнительным занятием и результатом.

# %% [markdown]
# ## nursery

# %%
df['nursery'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.763496
# no     0.197943
# NaN    0.038560
# Name: nursery, dtype: float64

# %%
df['nursery'].fillna('yes', inplace=True)
df[pd.isnull(df['nursery'])]
df['nursery'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.806202
# no     0.193798
# Name: nursery, dtype: float64

# %% [markdown]
# 81% учеников посещали детский сад

# %% [markdown]
# Предположение - этот столбец никак не влияет на результат.

# %%
print(df.groupby(['nursery'])['score'].count())
print(df.groupby(['nursery'])['score'].mean())
# Out:
# nursery
# no      75
# yes    312
# Name: score, dtype: int64
# nursery
# no     50.333333
# yes    52.820513
# Name: score, dtype: float64

# %% [markdown]
# Да, предположение подтвердилось.

# %% [markdown]
# ## studytime, granular

# %%
df['studytime, granular'].value_counts(dropna=False, normalize=True)
# Out:
# -6.0     0.485861
# -3.0     0.264781
# -9.0     0.161954
# -12.0    0.069409
#  NaN     0.017995
# Name: studytime, granular, dtype: float64

# %%
sns.boxplot(df['studytime, granular'])

# %%
df['studytime, granular'].fillna(-6.0, inplace=True)
df[pd.isnull(df['studytime, granular'])]
df['studytime, granular'].value_counts(dropna=False, normalize=True)
# Out:
# -6.0     0.506460
# -3.0     0.260982
# -9.0     0.162791
# -12.0    0.069767
# Name: studytime, granular, dtype: float64

# %% [markdown]
# Столбец без описание и с предположительным выбросом. Я прочитала, что в статистики термин granular используется для обозначения преобразованных данных, которые более детальны и их легче анализировать. Попробуем проверить, как связаны столбцы studytime, granular и studytime

# %%
df['st_test'] = df['studytime, granular'] / df['studytime']

# %%
df['st_test'].value_counts()
# Out:
# -3.0    387
# Name: st_test, dtype: int64

# %% [markdown]
# Похоже, что показатели в столбце studytime умножены на -3. И таким образом, мы получили обратный график на боксплоте. Возможно, это дает преимущество при аналитике, но я пока не поняла какое.

# %%
print(df.groupby(['studytime, granular'])['score'].count())
print(df.groupby(['studytime, granular'])['score'].mean())
# Out:
# studytime, granular
# -12.0     27
# -9.0      63
# -6.0     196
# -3.0     101
# Name: score, dtype: int64
# studytime, granular
# -12.0    56.296296
# -9.0     57.777778
# -6.0     51.403061
# -3.0     49.702970
# Name: score, dtype: float64

# %% [markdown]
# ## higher

# %%
df['higher'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.899743
# NaN    0.051414
# no     0.048843
# Name: higher, dtype: float64

# %%
df['higher'].fillna('yes', inplace=True)
df[pd.isnull(df['higher'])]
df['higher'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.953488
# no     0.046512
# Name: higher, dtype: float64

# %% [markdown]
# Возможно, в этом столбце стоило сделать отдельную графу с тем, кто не выбрал поступать или нет в высшее заведение. Но не совсем понимаю, от какого количества значений это имеет смысл делать.

# %% [markdown]
# 95% учеников планируют дальше получать высшее образование.

# %%
print(df.groupby(['higher'])['score'].count())
print(df.groupby(['higher'])['score'].mean())
# Out:
# higher
# no      18
# yes    369
# Name: score, dtype: int64
# higher
# no     33.333333
# yes    53.265583
# Name: score, dtype: float64

# %% [markdown]
# Те, кто планируют в дальнейшем продолжить учебу, сдают экзамен лучше.

# %% [markdown]
# ## internet

# %%
df['internet'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.771208
# no     0.141388
# NaN    0.087404
# Name: internet, dtype: float64

# %%
df['internet'].fillna('yes', inplace=True)
df[pd.isnull(df['internet'])]
df['internet'].value_counts(dropna=False, normalize=True)
# Out:
# yes    0.860465
# no     0.139535
# Name: internet, dtype: float64

# %% [markdown]
# У 86% есть интернет дома

# %% [markdown]
# Предположение - наличие интенета не влияет на результат.

# %%
print(df.groupby(['internet'])['score'].count())
print(df.groupby(['internet'])['score'].mean())
# Out:
# internet
# no      54
# yes    333
# Name: score, dtype: int64
# internet
# no     49.351852
# yes    52.822823
# Name: score, dtype: float64

# %% [markdown]
# Кажется, что наличие интернета действительно не сильно влияет на результат.

# %% [markdown]
# ## romantic

# %%
df['romantic'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.604113
# yes    0.316195
# NaN    0.079692
# Name: romantic, dtype: float64

# %%
df['romantic'].fillna('no', inplace=True)
df[pd.isnull(df['romantic'])]
df['romantic'].value_counts(dropna=False, normalize=True)
# Out:
# no     0.684755
# yes    0.315245
# Name: romantic, dtype: float64

# %% [markdown]
# 32% учеников в романтических отношениях, а 68% - нет.

# %% [markdown]
# Предположение - ученики с романтическими отношениями сдают экзамен хуже, чем без.

# %%
print(df.groupby(['romantic'])['score'].count())
print(df.groupby(['romantic'])['score'].mean())
# Out:
# romantic
# no     265
# yes    122
# Name: score, dtype: int64
# romantic
# no     54.452830
# yes    47.745902
# Name: score, dtype: float64

# %% [markdown]
# Да, предположение подтвердилось.

# %% [markdown]
# ## famrel

# %%
df['famrel'].value_counts(dropna=False, normalize=True)
# Out:
#  4.0    0.457584
#  5.0    0.249357
#  3.0    0.159383
#  NaN    0.069409
#  2.0    0.043702
#  1.0    0.017995
# -1.0    0.002571
# Name: famrel, dtype: float64

# %%
sns.boxplot(df['famrel'])

# %%
# предположим, что значение -1 появилось из-за опечатки и заменим его на 1.
df.loc[df['famrel'] == -1.0, 'famrel'] = 1.0

# %%
df['famrel'].fillna(4.0, inplace=True)
df[pd.isnull(df['famrel'])]
df['famrel'].value_counts(dropna=False, normalize=True)
# Out:
# 4.0    0.529716
# 5.0    0.245478
# 3.0    0.160207
# 2.0    0.043928
# 1.0    0.020672
# Name: famrel, dtype: float64

# %%
# проверяем изменения
sns.boxplot(df['famrel'])

# %% [markdown]
# В столбце про семейные отношения есть и выбросы, и пропуски. Пропуски я заменила на самый частотный, но после этого сместилось и распределение и получилось, что 52% учеников оценивают свои отношения с родителями, как нормальные. 24% как очень хорошие, 16% средние, 4% и 2% как плохие и очень плохие.

# %% [markdown]
# Предположение - у учеников с нормальными и очень хорошими отношениями оценки за экзамен выше. Поэтому пока это предположение не будет проверена, считаю, что не нужно удалять выбросы. Возможно, если влияние этого показателя высокое на целевую переменную, то имеет смысл попробовать другие способы заполения пропуска.

# %%
print(df.groupby(['famrel'])['score'].count())
print(df.groupby(['famrel'])['score'].mean())
# Out:
# famrel
# 1.0      8
# 2.0     17
# 3.0     62
# 4.0    205
# 5.0     95
# Name: score, dtype: int64
# famrel
# 1.0    53.125000
# 2.0    48.529412
# 3.0    51.451613
# 4.0    51.536585
# 5.0    55.263158
# Name: score, dtype: float64

# %% [markdown]
# Здесь, как и в studytime, видно одно крайнее значение равное 1.0, которое выбивается из общего графика. Мне кажется его можно удалить, так как оно выбивается из общей логики.

# %%
df = df[df.famrel != 1.0]

# %%
print(df.groupby(['famrel'])['score'].count())
print(df.groupby(['famrel'])['score'].mean())
# Out:
# famrel
# 2.0     17
# 3.0     62
# 4.0    201
# 5.0     93
# Name: score, dtype: int64
# famrel
# 2.0    48.529412
# 3.0    51.451613
# 4.0    51.592040
# 5.0    55.483871
# Name: score, dtype: float64

# %%
# проверяем изменения
sns.boxplot(df['famrel'])

# %% [markdown]
# ## freetime

# %%
df['freetime'].value_counts(dropna=False, normalize=True)
# Out:
# 3.0    0.390746
# 4.0    0.282776
# 2.0    0.161954
# 5.0    0.095116
# 1.0    0.046272
# NaN    0.023136
# Name: freetime, dtype: float64

# %%
sns.boxplot(df['freetime'])

# %%
df['freetime'].fillna(3.0, inplace=True)
df[pd.isnull(df['freetime'])]
df['freetime'].value_counts(dropna=False, normalize=True)
# Out:
# 3.0    0.416021
# 4.0    0.281654
# 2.0    0.162791
# 5.0    0.093023
# 1.0    0.046512
# Name: freetime, dtype: float64

# %%
sns.boxplot(df['freetime'])

# %% [markdown]
# В данном столбце есть выбросы и пропуски. Пропуски заменила на наиболее частотное значение, а выброс, который показывает, что 5% студентов считают, что у них очень мало свободного времени после школы, думаю, оставить и проверить есть ли зависимость между количеством свободного времени и итоговой оценкой (например, обратная пропорциональность).

# %%
print(df.groupby(['freetime'])['score'].count())
print(df.groupby(['freetime'])['score'].mean())
# Out:
# freetime
# 1.0     18
# 2.0     63
# 3.0    161
# 4.0    109
# 5.0     36
# Name: score, dtype: int64
# freetime
# 1.0    48.333333
# 2.0    57.539683
# 3.0    49.440994
# 4.0    52.752294
# 5.0    56.944444
# Name: score, dtype: float64

# %% [markdown]
# Не тот результат, что я ожидала увидеть, так как хуже всего среднее значение показали те, кто оценил, что у него очень мало свободного времени и достаточно.

# %% [markdown]
# ## goout

# %%
df['goout'].value_counts(dropna=False, normalize=True)
# Out:
# 3.0    0.323907
# 2.0    0.259640
# 4.0    0.208226
# 5.0    0.131105
# 1.0    0.059126
# NaN    0.017995
# Name: goout, dtype: float64

# %%
sns.boxplot(df['goout'])

# %%
df['goout'].fillna(3.0, inplace=True)
df[pd.isnull(df['goout'])]
df['goout'].value_counts(dropna=False, normalize=True)
# Out:
# 3.0    0.341085
# 2.0    0.260982
# 4.0    0.209302
# 5.0    0.129199
# 1.0    0.059432
# Name: goout, dtype: float64

# %%
sns.boxplot(df['goout'])

# %% [markdown]
# Выбросов в столбце не было, но были пропуски. 34% написали, что проводят достаточно времени с друзьями, 26% мало, 6% очень мало, 21% много, 12% очень много.

# %% [markdown]
# Предположение - те, кто проводят достаточно времени с друзьяит лучше оценки за экзамен.

# %%
print(df.groupby(['goout'])['score'].count())
print(df.groupby(['goout'])['score'].mean())
# Out:
# goout
# 1.0     23
# 2.0    101
# 3.0    132
# 4.0     81
# 5.0     50
# Name: score, dtype: int64
# goout
# 1.0    49.347826
# 2.0    55.990099
# 3.0    54.734848
# 4.0    49.506173
# 5.0    44.600000
# Name: score, dtype: float64

# %% [markdown]
# В целом, предположение подтвердилось.

# %% [markdown]
# ## health

# %%
df['health'].value_counts(dropna=False, normalize=True)
# Out:
# 5.0    0.352185
# 3.0    0.226221
# 4.0    0.154242
# 1.0    0.120823
# 2.0    0.107969
# NaN    0.038560
# Name: health, dtype: float64

# %%
sns.boxplot(df['health'])

# %%
df['health'].fillna(5.0, inplace=True)
df[pd.isnull(df['health'])]
df['health'].value_counts(dropna=False, normalize=True)
# Out:
# 5.0    0.392765
# 3.0    0.224806
# 4.0    0.155039
# 1.0    0.118863
# 2.0    0.108527
# Name: health, dtype: float64

# %% [markdown]
# 39% считают, что их текущее состояние очень хорошее, 16% - хорошее, 22% - нормальное, 10% и 12% оценивают свое здоровье, как плохое и очень плохое.

# %% [markdown]
# Предположение - те, кто чувствует себя хорошо или очень хорошо, лучше сдают экзамен.

# %%
print(df.groupby(['health'])['score'].count())
print(df.groupby(['health'])['score'].mean())
# Out:
# health
# 1.0     46
# 2.0     42
# 3.0     87
# 4.0     60
# 5.0    152
# Name: score, dtype: int64
# health
# 1.0    59.782609
# 2.0    52.619048
# 3.0    50.804598
# 4.0    50.833333
# 5.0    51.480263
# Name: score, dtype: float64

# %% [markdown]
# Интересно, что самый высокий средний балл, у тех, кто хуже всего себя чувствует.

# %% [markdown]
# ## absences

# %%
df['absences'].value_counts(dropna=False, normalize=True)
# Out:
# 0.0      0.282776
# 2.0      0.154242
# 4.0      0.133676
# 6.0      0.077121
# 8.0      0.051414
# 10.0     0.043702
# 12.0     0.030848
# 14.0     0.030848
# NaN      0.028278
# 16.0     0.017995
# 3.0      0.017995
# 7.0      0.015424
# 5.0      0.012853
# 18.0     0.012853
# 20.0     0.010283
# 1.0      0.007712
# 22.0     0.007712
# 9.0      0.007712
# 13.0     0.005141
# 15.0     0.005141
# 11.0     0.005141
# 25.0     0.002571
# 54.0     0.002571
# 385.0    0.002571
# 26.0     0.002571
# 56.0     0.002571
# 24.0     0.002571
# 212.0    0.002571
# 21.0     0.002571
# 75.0     0.002571
# 30.0     0.002571
# 19.0     0.002571
# 38.0     0.002571
# 40.0     0.002571
# 23.0     0.002571
# 17.0     0.002571
# 28.0     0.002571
# Name: absences, dtype: float64

# %%
df.absences.mean()
# Out:
# 7.308510638297872

# %%
df.absences.median()
# Out:
# 4.0

# %%
df.absences.mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['absences'].hist()

# %%
df['absences'].fillna(4.0, inplace=True)
df[pd.isnull(df['absences'])]
df['absences'].value_counts(dropna=False, normalize=True)
# Out:
# 0.0      0.284238
# 4.0      0.162791
# 2.0      0.155039
# 6.0      0.077519
# 8.0      0.051680
# 10.0     0.043928
# 12.0     0.031008
# 14.0     0.031008
# 3.0      0.015504
# 16.0     0.015504
# 7.0      0.015504
# 5.0      0.012920
# 18.0     0.012920
# 20.0     0.010336
# 22.0     0.007752
# 9.0      0.007752
# 1.0      0.007752
# 15.0     0.005168
# 13.0     0.005168
# 11.0     0.005168
# 25.0     0.002584
# 54.0     0.002584
# 385.0    0.002584
# 26.0     0.002584
# 56.0     0.002584
# 24.0     0.002584
# 212.0    0.002584
# 21.0     0.002584
# 75.0     0.002584
# 30.0     0.002584
# 19.0     0.002584
# 38.0     0.002584
# 40.0     0.002584
# 23.0     0.002584
# 17.0     0.002584
# 28.0     0.002584
# Name: absences, dtype: float64

# %%
df['absences'].hist()

# %%
sns.boxplot(df['absences'])

# %% [markdown]
# В столбце были пропуски - их заменила на медиану. На боксплоте видно, что большинство учатся без пропусков, но есть выбросы вплоть до пропуска всех занятий.

# %% [markdown]
# Предположение, чем меньше пропусков, тем лучше результат за экзамен, его проверим ниже, с помощью корреляционного анализа.

# %% [markdown]
# ## score

# %%
df['score'].value_counts(dropna=False, normalize=True)
# Out:
# 50.0     0.138817
# 55.0     0.118252
# 0.0      0.095116
# 75.0     0.084833
# 65.0     0.079692
# 40.0     0.079692
# 60.0     0.079692
# 70.0     0.069409
# 45.0     0.069409
# 80.0     0.041131
# 30.0     0.038560
# 90.0     0.030848
# 35.0     0.023136
# 25.0     0.017995
# 85.0     0.015424
# 95.0     0.012853
# 100.0    0.002571
# 20.0     0.002571
# Name: score, dtype: float64

# %%
df['score'].hist(bins=12)

# %% [markdown]
# Целевая переменная, были пропуски, которые удалила. В целом, похоже на нормальное распределение

# %% [markdown]
# ## Корреляционный анализ

# %%
# выбираем числовые столбцы для корреляционного анализа
df_corr = df.loc[:, ['age', 'absences', 'score']]

# %%
df_corr
# Out:
#      age  absences  score
# 0     18       6.0   30.0
# 1     17       4.0   30.0
# 2     15      10.0   50.0
# 3     15       2.0   75.0
# 4     16       4.0   50.0
# ..   ...       ...    ...
# 389   18       0.0    0.0
# 390   20     212.0   45.0
# 391   17       3.0   80.0
# 393   18       0.0   50.0
# 394   19       5.0   45.0
#
# [387 rows x 3 columns]

# %%
sns.pairplot(df_corr, kind='reg')

# %%
# используем для наглядности матрицу корреляций
df_corr.corr()
# Out:
#                age  absences     score
# age       1.000000  0.096756 -0.149173
# absences  0.096756  1.000000  0.062895
# score    -0.149173  0.062895  1.000000

# %% [markdown]
# Мы видим положительную корреляцию пропусков и результат за экзамена, что не ожидаемо, и отрицательную - возраста и результат за экзамена. Но все переменные сласбоскоррелированы.

# %% [markdown]
# ## Анализ номинативных переменных

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize=(14, 4))
    sns.boxplot(x=column, y='score',
                data=df,
                ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
# проверим, какие колонки остались в нашем датасете
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score', 'Pedu', 'MPedu',
#        'PPedu', 'other_guardian', 'st_test', 'any_sup'],
#       dtype='object')

# %%
# выбираем колонки, чтобы провести анализ номинативных переменных
for col in ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
            'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
            'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
            'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
            'freetime', 'goout', 'health', 'Pedu', 'MPedu', 'other_guardian',
            'PPedu', 'any_sup']:
    get_boxplot(col)

# %% [markdown]
# Анализируя боксплоты, можно сказать, что на балл за экзамен влияет параметр Medu, Fedu, failures, higher, freetime, gout, Pedu.

# %% [markdown]
# Проверим, есть ли статистическая разница в распределении оценок по номинативным признакам, с помощью теста Стьюдента. Проверим нулевую гипотезу о том, что распределения оценок батончиков по различным параметрам неразличимы:

# %%
def get_stat_dif(column):
    cols = df.loc[:, column].value_counts().index
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(df.loc[df.loc[:, column] == comb[0], 'score'],
                     df.loc[df.loc[:, column] == comb[1], 'score']).pvalue \
                <= 0.05/len(combinations_all):  # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
for col in ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
            'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
            'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
            'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
            'freetime', 'goout', 'health', 'absences', 'Pedu', 'other_guardian', 'any_sup']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки address
# Найдены статистически значимые различия для колонки Medu
# Найдены статистически значимые различия для колонки Mjob
# Найдены статистически значимые различия для колонки failures
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic
# Найдены статистически значимые различия для колонки Pedu

# %% [markdown]
# ## Выводы

# %% [markdown]
# Итак, в результате EDA для анализа влияния параметров на результаты экзамена по матемитике были получены следующие выводы:
#
# * В данных достаточно мало пустых значений - Pstatus, paid, fumsup, Fjob - в этих столбцах пропусков больше, чем 9%. Все пропуски были заменены на наиболее частотное значение.
# * Выбросы найдены в столбцах age, famrel, Fedu, traveltime, studytime, granular, romantic, freetime. В зависимости от ситуации выбросы были либо удалены, либо оставлены, как содержащие важную информацию.
# * Положительная корреляция параметра review_date и rating может говорить о том, что с годами рейтинги потихоньку завышаются, либо батончики становятся лучше.
# * Самые важные параметры, которые предлагается использовать в дальнейшем для построения модели, это age, Pedu, sex, adress, Mjob, failures, higher, romantic, any_sup, traveltime.

# %% [markdown]
# ## Подготовка таблицы для построения модели

# %%
# проверяем какие остались стобцы
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score', 'Pedu', 'MPedu',
#        'PPedu', 'other_guardian', 'st_test', 'any_sup'],
#       dtype='object')

# %%
# создаем новый датафрейм
selected_columns = df[['age', 'Pedu', 'sex', 'address', 'Mjob',
                       'failures', 'higher', 'romantic', 'any_sup', 'traveltime']]
df_test = selected_columns.copy()
df_test
# Out:
#      age  Pedu sex address      Mjob  failures higher romantic  any_sup  \
# 0     18   4.0   F       U   at_home       0.0    yes       no        1
# 1     17   1.0   F       U   at_home       0.0    yes       no        1
# 2     15   1.0   F       U   at_home       3.0    yes       no        1
# 3     15   4.0   F       U    health       0.0    yes      yes        1
# 4     16   3.0   F       U     other       0.0    yes       no        1
# ..   ...   ...  ..     ...       ...       ...    ...      ...      ...
# 388   18   3.0   F       U   teacher       0.0    yes       no        1
# 390   20   2.0   M       U  services       2.0    yes       no        1
# 391   17   3.0   M       U  services       0.0    yes       no        0
# 393   18   3.0   M       R  services       0.0    yes       no        0
# 394   19   1.0   M       U     other       0.0    yes       no        0
#
#      traveltime
# 0           2.0
# 1           1.0
# 2           1.0
# 3           1.0
# ...

# %%
# Create a label encoder object
le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in df_test:
    if df_test[col].dtype == 'object':
        # If 2 or fewer unique categories
        if len(list(df_test[col].unique())) <= 2:
            # Train on the training data
            le.fit(df_test[col])
            # Transform both training and testing data
            df_test[col] = le.transform(df_test[col])

            # Keep `track of how many columns were label encoded
            le_count += 1

print('%d columns were label encoded.' % le_count)
# Out:
# 3 columns were label encoded.

# %%
# one-hot encoding of categorical variables
df_test = pd.get_dummies(df_test)

print('Training Features shape: ', df_test.shape)
# Out:
# Training Features shape:  (373, 14)

# %% [markdown]
# ## Комментарии

# %% [markdown]
# * Не владею терминологией и пока еще не совсем понимаю, что именно будет происходить с данными. Есть много пробелов в понимании самой статистики. Если будут комментарии, где я что не так употребила - здорово.
# * Не поняла, в каком случае стоит выделать отдельный столбец для данных. И последовательность - нужно в начале заполнять пропуски, а потом смотреть корреляцию между переменными или наоборот.
# * Еще был вариант распределить студунтов по группам, в зависимости от оценки и посмотреть какие параметры преобладают или оказывают влияние, но я не уверена, что это правильное направление рассуждений.
# * Про предположения, писала их для каждого параметра - правильно ли это делать?
# * Когда получаем статистически значимые различия для колонок, то только их включать в окончательную таблицу? В вывод я добавила все столбцы, которые показались в ходе анализа важными. Не знаю, правильно ли это.
# * Я добавила на всякий случай графу с ресурсами, чтобы показать, что использовала в подготовке.

# %% [markdown]
# ## Ресурсы

# %% [markdown]
# * https://www.techopedia.com/definition/31722/granular-data
# * https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python
# * https://www.kaggle.com/pmarcelino/data-analysis-and-feature-extraction-with-python/data
# * https://www.kaggle.com/kanncaa1/data-sciencetutorial-for-beginners
# * https://www.kaggle.com/willkoehrsen/start-here-a-gentle-introduction
# * Статистика и котики, Савельев Владимир

# %% [markdown]
# → основные цели и задачи проекта;
# Провести первичную обработку данных и отобрать переменные, которые могут влиять на успеваемость по математике учеников в возрасте от 15 до 22 лет, для того, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.
# В дальнейшем на основе отобранных переменных, будет построена модель, для своевременного определения учеников в группе риска.
#
# → краткую информацию о данных;
# Данные в хорошем состоянии, с небольшим количеством пропусков и выбросов.
#
# → этапы работы над проектом.
# Были проверены все параметры на наличие пропусков и выбросов, проведен корреляционный анализ, проведен анализ номинативных параметров, выбраны самые важные параметры.
#
# → ответы на вопросы саморефлексии:
#
# 1. Какова была ваша роль в команде? Делала самостоятельно.
#
# 2. Какой частью своей работы вы остались особенно довольны? Мне было интересно аналазировать каждый параметр отдельно и хотелось бы еще побольше времени уделить на поиск взаимосвязей.
#
# 3. Что не получилось сделать так, как хотелось? Над чем ещё стоит поработать? Не получилось сделать проект за 8-10 часов. Мне кажется, что потратила около 30 часов, но есть еще что дорабатывать. Думаю, что стоит собрать список из основных функций, шаблонов для обработки и это ускорит процесс.
#
# 4. Что интересного и полезного вы узнали в этом модуле? Много о статистике.
#
# 5. Что является вашим главным результатом при прохождении этого проекта? Попробовала на практике, как происходит подготовка данных.
#
# 6. Какие навыки вы уже можете применить в текущей деятельности? Выучила горячие клавишы, улучшила работу с пандас.
#
# 7. Планируете ли вы дополнительно изучать материалы по теме проекта? Да, особенно по статистике.
